# %% [markdown]
# <a href="https://colab.research.google.com/github/MuizSarwar/learnML/blob/main/Sigmoid_Function_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import all libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Define sigmoid function :
def sigmoid(z):
  return 1 / ( 1 + np.exp(-z))

# %%
#plot the sigmoid curve:
z_grid = np.linspace(-10, 10, 500)
proba_grid = sigmoid(z_grid)
plt.figure(figsize=(7, 5))
plt.plot(z_grid, proba_grid)
plt.axhline(0.5, linestyle="--", color="black")
plt.axvline(0, linestyle="--", color="black")
plt.xlabel("z")
plt.ylabel("Probability")
plt.title("Sigmoid function")
plt.show()

# %%
#Simple threshold demostration:
threshold = 0.5
pred_class = (proba_grid >= threshold).astype(int)
